# %% [markdown]
# # Run skbio single cell tutorial
#
# ## Ref:
# https://github.com/scikit-bio/scikit-bio-tutorials?tab=readme-ov-file
#
# with google colab

# %%
import skbio

print(f"skbio version:{skbio.__version__}")

import scanpy

print(f"scanpy version:{scanpy.__version__}")
# Out:
# skbio version:0.7.1.post1
# scanpy version:1.11.5
# /tmp/ipykernel_300353/2512705957.py:7: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(f"scanpy version:{scanpy.__version__}")

# %% [markdown]
# + PCA vs ICA before embedding
# (please read more)
# https://www.biostars.org/p/392646/
#
# + Galaxy tutorial, please read to understand.
#
# https://github.com/CedarsDSN/Galaxy_tutorial_scRNAseq_analysis/tree/main/docs

# %% [markdown]
# sc RNASeq in python
#
# https://www.sc-best-practices.org/preprocessing_visualization/normalization.html

# %% [markdown]
# ## Beta diversity in sk-bio
#
# In sk-bio beta-diversity is another name of doing between-pair distance!!
#
#         Mathematically, it is the pairwise distance / dissimilarity between two vectors.
